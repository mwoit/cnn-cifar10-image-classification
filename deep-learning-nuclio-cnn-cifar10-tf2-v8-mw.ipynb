# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %% [markdown]
# ### 2. Arquitectura de red del modelo - Proyecto 1

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.2))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.2))

model.add(ks.layers.Conv2D(512, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(512, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 5,982,922
# Trainable params: 5,982,922
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
Lazy_Adam = ks.optimizers.Adam(learning_rate=0.0003)

# %%
model.compile(optimizer=Lazy_Adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
# Usamos Early Stopping con patience 15
control_accuracy = EarlyStopping(monitor='val_accuracy', patience=15)

# %%
t = time.perf_counter()

# %%
# Fijamos epochs 50 y batch size 512
history = model.fit(x_train_scaled, y_train, epochs=150, 
                    use_multiprocessing=False, batch_size= 512, 
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/150
# 79/79 [==============================] - 6s 68ms/step - loss: 2.1068 - accuracy: 0.2006 - val_loss: 1.8739 - val_accuracy: 0.3135
# Epoch 2/150
# 79/79 [==============================] - 5s 62ms/step - loss: 1.7604 - accuracy: 0.3336 - val_loss: 1.6256 - val_accuracy: 0.3998
# Epoch 3/150
# 79/79 [==============================] - 5s 62ms/step - loss: 1.5351 - accuracy: 0.4260 - val_loss: 1.4359 - val_accuracy: 0.4697
# Epoch 4/150
# 79/79 [==============================] - 5s 63ms/step - loss: 1.3760 - accuracy: 0.4884 - val_loss: 1.2914 - val_accuracy: 0.5212
# Epoch 5/150
# 79/79 [==============================] - 5s 62ms/step - loss: 1.2528 - accuracy: 0.5374 - val_loss: 1.2770 - val_accuracy: 0.5422
# Epoch 6/150
# 79/79 [==============================] - 5s 64ms/step - loss: 1.1587 - accuracy: 0.5775 - val_loss: 1.0483 - val_accuracy: 0.6160
# Epoch 7/150
# 79/79 [==============================] - 5s 62ms/step - loss: 1.0794 - accuracy: 0.6097 - val_loss: 1.0846 - val_accuracy: 0.6090
# Epoch 8/150
# 79/79 [==============================] - 5s 62ms/step - loss: 1.0012 - accuracy: 0.6409 - val_loss: 1.0197 - val_accuracy: 0.6333
# Epoch 9/150
# 79/79 [==============================] - 5s 66ms/step - loss: 0.9384 - accuracy: 0.6634 - val_loss: 0.9249 - val_accuracy: 0.6701
# Epoch 10/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.8705 - accuracy: 0.6902 - val_loss: 0.8278 - val_accuracy: 0.7075
# Epoch 11/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.8230 - accuracy: 0.7074 - val_loss: 0.8310 - val_accuracy: 0.7053
# Epoch 12/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.7812 - accuracy: 0.7237 - val_loss: 0.8146 - val_accuracy: 0.7177
# Epoch 13/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.7386 - accuracy: 0.7405 - val_loss: 0.7489 - val_accuracy: 0.7406
# Epoch 14/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.6700 - accuracy: 0.7632 - val_loss: 0.7311 - val_accuracy: 0.7433
# Epoch 15/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.6253 - accuracy: 0.7818 - val_loss: 0.8226 - val_accuracy: 0.7234
# Epoch 16/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.5784 - accuracy: 0.7973 - val_loss: 0.6953 - val_accuracy: 0.7591
# Epoch 17/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.5332 - accuracy: 0.8135 - val_loss: 0.6644 - val_accuracy: 0.7763
# Epoch 18/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.4931 - accuracy: 0.8272 - val_loss: 0.6951 - val_accuracy: 0.7705
# Epoch 19/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.4730 - accuracy: 0.8341 - val_loss: 0.6810 - val_accuracy: 0.7660
# Epoch 20/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.4226 - accuracy: 0.8520 - val_loss: 0.6446 - val_accuracy: 0.7955
# Epoch 21/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.3939 - accuracy: 0.8626 - val_loss: 0.6669 - val_accuracy: 0.7814
# Epoch 22/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.3506 - accuracy: 0.8751 - val_loss: 0.6440 - val_accuracy: 0.7943
# Epoch 23/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.3276 - accuracy: 0.8848 - val_loss: 0.7589 - val_accuracy: 0.7758
# Epoch 24/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.2859 - accuracy: 0.8998 - val_loss: 0.6968 - val_accuracy: 0.7881
# Epoch 25/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.2572 - accuracy: 0.9100 - val_loss: 0.6621 - val_accuracy: 0.8030
# Epoch 26/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.2374 - accuracy: 0.9177 - val_loss: 0.7136 - val_accuracy: 0.7896
# Epoch 27/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.2022 - accuracy: 0.9281 - val_loss: 0.7257 - val_accuracy: 0.8022
# Epoch 28/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1636 - accuracy: 0.9427 - val_loss: 0.7341 - val_accuracy: 0.8040
# Epoch 29/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1649 - accuracy: 0.9423 - val_loss: 0.7729 - val_accuracy: 0.8009
# Epoch 30/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1574 - accuracy: 0.9457 - val_loss: 0.7618 - val_accuracy: 0.8079
# Epoch 31/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1385 - accuracy: 0.9513 - val_loss: 0.8495 - val_accuracy: 0.7919
# Epoch 32/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1202 - accuracy: 0.9581 - val_loss: 0.8091 - val_accuracy: 0.8064
# Epoch 33/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1188 - accuracy: 0.9586 - val_loss: 0.8620 - val_accuracy: 0.7951
# Epoch 34/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0975 - accuracy: 0.9662 - val_loss: 0.8314 - val_accuracy: 0.8031
# Epoch 35/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0922 - accuracy: 0.9679 - val_loss: 0.8841 - val_accuracy: 0.8063
# Epoch 36/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0853 - accuracy: 0.9709 - val_loss: 0.8665 - val_accuracy: 0.8080
# Epoch 37/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0723 - accuracy: 0.9758 - val_loss: 0.9125 - val_accuracy: 0.8089
# Epoch 38/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0808 - accuracy: 0.9718 - val_loss: 0.8591 - val_accuracy: 0.8085
# Epoch 39/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0759 - accuracy: 0.9749 - val_loss: 0.8238 - val_accuracy: 0.8145
# Epoch 40/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0703 - accuracy: 0.9771 - val_loss: 0.9060 - val_accuracy: 0.8101
# Epoch 41/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0631 - accuracy: 0.9784 - val_loss: 0.8874 - val_accuracy: 0.8097
# Epoch 42/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0601 - accuracy: 0.9794 - val_loss: 0.9788 - val_accuracy: 0.8039
# Epoch 43/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0664 - accuracy: 0.9780 - val_loss: 0.8999 - val_accuracy: 0.8115
# Epoch 44/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0587 - accuracy: 0.9808 - val_loss: 0.9420 - val_accuracy: 0.8094
# Epoch 45/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0550 - accuracy: 0.9823 - val_loss: 0.9615 - val_accuracy: 0.8050
# Epoch 46/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0492 - accuracy: 0.9834 - val_loss: 0.9633 - val_accuracy: 0.8100
# Epoch 47/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0529 - accuracy: 0.9823 - val_loss: 1.0007 - val_accuracy: 0.8096
# Epoch 48/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0502 - accuracy: 0.9832 - val_loss: 0.9590 - val_accuracy: 0.8105
# Epoch 49/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0546 - accuracy: 0.9821 - val_loss: 0.9486 - val_accuracy: 0.8118
# Epoch 50/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0421 - accuracy: 0.9859 - val_loss: 1.0487 - val_accuracy: 0.8018
# Epoch 51/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0555 - accuracy: 0.9819 - val_loss: 1.0066 - val_accuracy: 0.8098
# Epoch 52/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0439 - accuracy: 0.9862 - val_loss: 0.9891 - val_accuracy: 0.8070
# Epoch 53/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0511 - accuracy: 0.9822 - val_loss: 0.9578 - val_accuracy: 0.8094
# Epoch 54/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0434 - accuracy: 0.9855 - val_loss: 1.0028 - val_accuracy: 0.8076
# Epoch 55/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0421 - accuracy: 0.9859 - val_loss: 1.0053 - val_accuracy: 0.8098
# Epoch 56/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 1.0476 - val_accuracy: 0.8104
# Epoch 57/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0394 - accuracy: 0.9866 - val_loss: 1.0240 - val_accuracy: 0.8098
# Epoch 58/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0367 - accuracy: 0.9875 - val_loss: 1.0014 - val_accuracy: 0.8098
# Epoch 59/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0400 - accuracy: 0.9865 - val_loss: 0.9918 - val_accuracy: 0.8161
# Epoch 60/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0305 - accuracy: 0.9893 - val_loss: 1.0474 - val_accuracy: 0.8122
# Epoch 61/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0372 - accuracy: 0.9873 - val_loss: 1.0025 - val_accuracy: 0.8116
# Epoch 62/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0483 - accuracy: 0.9851 - val_loss: 1.0190 - val_accuracy: 0.8162
# Epoch 63/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.9856 - val_accuracy: 0.8166
# Epoch 64/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0317 - accuracy: 0.9895 - val_loss: 1.0652 - val_accuracy: 0.8071
# Epoch 65/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 1.0772 - val_accuracy: 0.8083
# Epoch 66/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 1.1117 - val_accuracy: 0.8036
# Epoch 67/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0424 - accuracy: 0.9861 - val_loss: 1.0238 - val_accuracy: 0.8113
# Epoch 68/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 1.0181 - val_accuracy: 0.8158
# Epoch 69/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0296 - accuracy: 0.9899 - val_loss: 1.0761 - val_accuracy: 0.8039
# Epoch 70/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 1.0429 - val_accuracy: 0.8133
# Epoch 71/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 1.1197 - val_accuracy: 0.8095
# Epoch 72/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0319 - accuracy: 0.9898 - val_loss: 0.9980 - val_accuracy: 0.8117
# Epoch 73/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0349 - accuracy: 0.9892 - val_loss: 1.0183 - val_accuracy: 0.8148
# Epoch 74/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0329 - accuracy: 0.9889 - val_loss: 1.0661 - val_accuracy: 0.8068
# Epoch 75/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 1.0405 - val_accuracy: 0.8101
# Epoch 76/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0305 - accuracy: 0.9902 - val_loss: 1.1053 - val_accuracy: 0.8134
# Epoch 77/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0270 - accuracy: 0.9909 - val_loss: 1.0731 - val_accuracy: 0.8137
# Epoch 78/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0252 - accuracy: 0.9915 - val_loss: 1.0409 - val_accuracy: 0.8111
# Epoch 79/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 1.0764 - val_accuracy: 0.8112
# Epoch 80/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 1.0464 - val_accuracy: 0.8171
# Epoch 81/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0323 - accuracy: 0.9885 - val_loss: 1.1586 - val_accuracy: 0.8025
# Epoch 82/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0335 - accuracy: 0.9895 - val_loss: 1.0366 - val_accuracy: 0.8107
# Epoch 83/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 1.1715 - val_accuracy: 0.8028
# Epoch 84/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0277 - accuracy: 0.9914 - val_loss: 1.0981 - val_accuracy: 0.8132
# Epoch 85/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 1.0226 - val_accuracy: 0.8169
# Epoch 86/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 1.1202 - val_accuracy: 0.8035
# Epoch 87/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0377 - accuracy: 0.9875 - val_loss: 1.0136 - val_accuracy: 0.8132
# Epoch 88/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 1.0884 - val_accuracy: 0.8051
# Epoch 89/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 1.0836 - val_accuracy: 0.8158
# Epoch 90/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 1.1507 - val_accuracy: 0.8073
# Epoch 91/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 1.0905 - val_accuracy: 0.8122
# Epoch 92/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 1.0560 - val_accuracy: 0.8166
# Epoch 93/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 1.1938 - val_accuracy: 0.7965
# Epoch 94/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0480 - accuracy: 0.9848 - val_loss: 1.1314 - val_accuracy: 0.8071
# Epoch 95/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0276 - accuracy: 0.9908 - val_loss: 1.0886 - val_accuracy: 0.8152
# Epoch 96/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.9992 - val_accuracy: 0.8139
# Epoch 97/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 1.1214 - val_accuracy: 0.8173
# Epoch 98/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 1.1185 - val_accuracy: 0.8114
# Epoch 99/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 1.0896 - val_accuracy: 0.8129
# Epoch 100/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 1.1747 - val_accuracy: 0.8156
# Epoch 101/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 1.1400 - val_accuracy: 0.8148
# Epoch 102/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0255 - accuracy: 0.9919 - val_loss: 1.0729 - val_accuracy: 0.8142
# Epoch 103/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 1.0420 - val_accuracy: 0.8156
# Epoch 104/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 1.0885 - val_accuracy: 0.8131
# Epoch 105/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 1.0976 - val_accuracy: 0.8165
# Epoch 106/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0217 - accuracy: 0.9929 - val_loss: 1.0910 - val_accuracy: 0.8175
# Epoch 107/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 1.1234 - val_accuracy: 0.8153
# Epoch 108/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0236 - accuracy: 0.9934 - val_loss: 1.0241 - val_accuracy: 0.8169
# Epoch 109/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 1.0931 - val_accuracy: 0.8158
# Epoch 110/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 1.1447 - val_accuracy: 0.8069
# Epoch 111/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 1.0800 - val_accuracy: 0.8106
# Epoch 112/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 1.0583 - val_accuracy: 0.8128
# Epoch 113/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0191 - accuracy: 0.9941 - val_loss: 1.0519 - val_accuracy: 0.8173
# Epoch 114/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 1.1314 - val_accuracy: 0.8160
# Epoch 115/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0168 - accuracy: 0.9943 - val_loss: 1.2018 - val_accuracy: 0.8091
# Epoch 116/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 1.1424 - val_accuracy: 0.8122
# Epoch 117/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 1.0981 - val_accuracy: 0.8138
# Epoch 118/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 1.1293 - val_accuracy: 0.8076
# Epoch 119/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 1.1045 - val_accuracy: 0.8123
# Epoch 120/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 1.1027 - val_accuracy: 0.8178
# Epoch 121/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 1.1361 - val_accuracy: 0.8094
# Epoch 122/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 1.1672 - val_accuracy: 0.8146
# Epoch 123/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 1.1795 - val_accuracy: 0.8138
# Epoch 124/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 1.1097 - val_accuracy: 0.8135
# Epoch 125/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 1.2314 - val_accuracy: 0.8091
# Epoch 126/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 1.1517 - val_accuracy: 0.8142
# Epoch 127/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 1.1162 - val_accuracy: 0.8191
# Epoch 128/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 1.1826 - val_accuracy: 0.8124
# Epoch 129/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0234 - accuracy: 0.9921 - val_loss: 1.1161 - val_accuracy: 0.8123
# Epoch 130/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 1.2098 - val_accuracy: 0.8162
# Epoch 131/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 1.1192 - val_accuracy: 0.8163
# Epoch 132/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 1.1300 - val_accuracy: 0.8196
# Epoch 133/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 1.2196 - val_accuracy: 0.8137
# Epoch 134/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0284 - accuracy: 0.9914 - val_loss: 1.1057 - val_accuracy: 0.8161
# Epoch 135/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 1.1588 - val_accuracy: 0.8130
# Epoch 136/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 1.1660 - val_accuracy: 0.8134
# Epoch 137/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 1.1309 - val_accuracy: 0.8182
# Epoch 138/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 1.1985 - val_accuracy: 0.8184
# Epoch 139/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0178 - accuracy: 0.9944 - val_loss: 1.1439 - val_accuracy: 0.8226
# Epoch 140/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 1.1322 - val_accuracy: 0.8155
# Epoch 141/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 1.1433 - val_accuracy: 0.8159
# Epoch 142/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 1.1568 - val_accuracy: 0.8160
# Epoch 143/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 1.1722 - val_accuracy: 0.8172
# Epoch 144/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 1.2791 - val_accuracy: 0.8158
# Epoch 145/150
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 1.1803 - val_accuracy: 0.8141
# Epoch 146/150
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 1.1821 - val_accuracy: 0.8141
# Epoch 147/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 1.1149 - val_accuracy: 0.8160
# Epoch 148/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 1.1649 - val_accuracy: 0.8106
# Epoch 149/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 1.1514 - val_accuracy: 0.8137
# Epoch 150/150
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 1.1156 - val_accuracy: 0.8126

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:12:20.875787

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.680

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
# Aquí iria el codigo para conectarse a Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
ruta_googledrive = "/content/drive/MyDrive/Data Science - Nuclio/Proyectos Cifar10/" # A revisar en vuestra instancia

#model.save(ruta_googledrive+'cifar10_model_v6.h5')
model.save('cifar10_model_v8.h5')
